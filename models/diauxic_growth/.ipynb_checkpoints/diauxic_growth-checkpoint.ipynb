# %% [markdown]
# # diauxic_growth

# %%
from __future__ import absolute_import, print_function, division
import os
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import cobra
import roadrunner

from IPython.display import display, HTML

import sbmlutils
from sbmlutils import dfba
from sbmlutils.dfba.simulator import simulate_dfba
from sbmlutils.dfba import utils

print('sbmlutils:', sbmlutils.__version__)
print('cobra:', cobra.__version__)
print('roadrunner:', roadrunner.__version__)

print(os.getcwd())
# Out:
# sbmlutils: 0.1.5a6
# cobra: 0.6.1
# roadrunner: 1.4.18; Compiler: gcc 4.8.2, C++ version: 199711; JIT Compiler: LLVM-3.3; Date: May 17 2017, 17:36:55; LibSBML Version: 5.14.0
# /home/mkoenig/git/dfba/models/diauxic_growth

# %% [markdown]
# ## Simulation settings

# %%
model_id = "diauxic_growth"
tend = 20.0
dt = 0.05

# %%
def plot_results(df, mid):
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(14, 14))
    kwargs = {}
    for ax in (ax1, ax2):
        ax.plot(df.time, df['[Ac]'], color='darkred', label="Ac", **kwargs)
        ax.plot(df.time, df['[Glcxt]'], color='darkblue', label="Glcxt", **kwargs)
        ax.plot(df.time, df['[O2]'], color='darkgreen', label="O2", **kwargs)

    for ax in (ax3, ax4):
        ax.plot(df.time, df['[X]'], color='black', label="X biomass", **kwargs)

    ax2.set_yscale('log')
    ax2.set_ylim([10E-5, 15])
    ax4.set_yscale('log')

    for ax in (ax1, ax2):
        ax.set_ylabel('Concentration [?]')

    for ax in (ax3, ax4):
        ax.set_ylabel('Biomass [?]')

    for ax in (ax1, ax2):
        ax.set_title(mid)
        ax.set_xlabel('time [h]')
        ax.legend()
    plt.show()
    return fig

# %% [markdown]
# ## mk_model

# %%
version_mk = 'v11'
sbml_mk = './mk/{}/diauxic_top.xml'.format(version_mk)
mid_mk = '{}_mk_{}-sbmlutils'.format(model_id, version_mk)
print(sbml_mk)
print(mid_mk)

# run simulation 
df_mk, dfba_model_mk, dfba_simulator_mk = simulate_dfba(sbml_mk, tend=tend, dt=dt)
display(df_mk.head())
df_mk.to_csv('./{}.csv'.format(mid_mk))

fig = plot_results(df_mk, mid_mk)
fig.savefig('./{}.png'.format(mid_mk), bbox_inches='tight')
# Out:
# ./mk/v11/diauxic_top.xml
# diauxic_growth_mk_v11-sbmlutils
#
# Simulation time     : 0.904 [s]
# Total time          : 0.982 [s]
# Overhead time       : 0.078 [s] (8.0 %)
#       time      [Ac]    [Glcxt]      [O2]       [X]  [dummy_S]  [fba__Ac]  \
# 0.00  0.00  0.400000  10.800000  0.210000  0.001000        0.0        0.0
# 0.05  0.05  0.399921  10.799487  0.209356  0.001056        0.0        0.0
# 0.10  0.10  0.399838  10.798945  0.208877  0.001116        0.0        0.0
# 0.15  0.15  0.399750  10.798372  0.208509  0.001178        0.0        0.0
# 0.20  0.20  0.399657  10.797767  0.208217  0.001245        0.0        0.0
#
#       [fba__Glcxt]  [fba__O2]  [fba__X]   ...     lb_EX_O2  lb_EX_X    pEX_Ac  \
# 0.00           0.0        0.0       0.0   ...        -15.0    -10.0 -1.533756
# 0.05           0.0        0.0       0.0   ...        -15.0    -10.0 -1.533757
# 0.10           0.0        0.0       0.0   ...        -15.0    -10.0 -1.533758
# 0.15           0.0        0.0       0.0   ...        -15.0    -10.0 -1.533759
# 0.20           0.0        0.0       0.0   ...        -15.0    -10.0 -1.533761
#
#       pEX_Glcxt  pEX_O2     pEX_X  ub_EX_Ac  ub_EX_Glcxt  ub_EX_O2  ub_EX_X
# 0.00  -9.986130   -15.0  1.094515    1000.0       1000.0    1000.0   1000.0
# 0.05  -9.986130   -15.0  1.094514    1000.0       1000.0    1000.0   1000.0
# 0.10  -9.986129   -15.0  1.094514    1000.0       1000.0    1000.0   1000.0
# 0.15  -9.986128   -15.0  1.094514    1000.0       1000.0    1000.0   1000.0
# 0.20  -9.986128   -15.0  1.094514    1000.0       1000.0    1000.0   1000.0
#
# [5 rows x 49 columns]

# %% [markdown]
# ## lw model

# %%
version_lw = 'v4'
sbml_lw = './lw/{}/growth_top.xml'.format(version_lw)
mid_lw = '{}_lw_{}-sbmlutils'.format(model_id, version_lw)
print(sbml_lw)
print(mid_lw)

# run simulation 
df_lw, dfba_model_lw, dfba_simulator_lw = simulate_dfba(sbml_lw, tend=tend, dt=dt)
display(df_lw.head())
df_lw.to_csv('./{}.csv'.format(mid_lw))

fig = plot_results(df_lw, mid_lw)
fig.savefig('./{}.png'.format(mid_lw), bbox_inches='tight')
# Out:
# ./lw/v4/growth_top.xml
# diauxic_growth_lw_v4-sbmlutils
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-e5d3068453bb> in <module>()
#       6
#       7 # run simulation
# ----> 8 df_lw, dfba_model_lw, dfba_simulator_lw = simulate_dfba(sbml_lw, tend=tend, dt=dt)
#       9 display(df_lw.head())
#      10 df_lw.to_csv('./{}.csv'.format(mid_lw))
#
# /home/mkoenig/envs/dfba/src/sbmlutils/sbmlutils/dfba/simulator.py in simulate_dfba(sbml_path, tstart, tend, dt, pfba, abs_tol, rel_tol, lp_solver, **kwargs)
#      40     start_time = timeit.default_timer()
#      41     # Load model
# ---> 42     dfba_model = DFBAModel(sbml_path=sbml_path)
#      43
#      44     # simulation
#
# /home/mkoenig/envs/dfba/src/sbmlutils/sbmlutils/dfba/model.py in __init__(self, sbml_path)
#      57
#      58             self._process_top()
# ---> 59             self._process_models()
#      60             self._process_dt()
#      61
#
# /home/mkoenig/envs/dfba/src/sbmlutils/sbmlutils/dfba/model.py in _process_models(self)
#     190         mixed_sbml_cleaned = tempfile.NamedTemporaryFile("w", suffix=".xml")
#     191         libsbml.writeSBMLToFile(self.doc_top, mixed_sbml_cleaned.name)
# --> 192         self.rr_comp = roadrunner.RoadRunner(mixed_sbml_cleaned.name)
#     193
#     194         ###########################
#
# /home/mkoenig/envs/dfba/local/lib/python2.7/site-packages/roadrunner/roadrunner.pyc in _new_init(self, *args)
#    3454
#    3455     def _new_init(self, *args):
# -> 3456         RoadRunner._swig_init(self, *args)
#    3457         RoadRunner._makeProperties(self)
#    3458
#
# /home/mkoenig/envs/dfba/local/lib/python2.7/site-packages/roadrunner/roadrunner.pyc in __init__(self, *args)
#    2520
#    2521     def __init__(self, *args):
# -> 2522         this = _roadrunner.new_RoadRunner(*args)
#    2523         try:
#    2524             self.this.append(this)
#
# RuntimeError: Unknown ASTNode type of 321, from <assignmentRule metaid="C3__rule1" variable="a_uptake_max">
#   <math xmlns="http://www.w3.org/1998/Math/MathML">
#     <apply>
#       <min/>
#       <cn type="integer"> 1000 </cn>
#       <apply>
#         <divide/>
#         <ci> Ac </ci>
#         <apply>
#           <times/>
#           <ci> C3__max_X </ci>
#           <ci> dt </ci>
#         </apply>
#       </apply>
#     </apply>
#   </math>
# </assignmentRule>, at llvm::Value* rrllvm::ASTNodeCodeGen::codeGen(const libsbml::ASTNode*)
