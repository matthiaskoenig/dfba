# %% [markdown]
# # diauxic_growth

# %%
from __future__ import absolute_import, print_function, division
import os
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import cobra
import roadrunner

from IPython.display import display, HTML

import sbmlutils
from sbmlutils import dfba
from sbmlutils.dfba.simulator import simulate_dfba
from sbmlutils.dfba import utils

print('sbmlutils:', sbmlutils.__version__)
print('cobra:', cobra.__version__)
print('roadrunner:', roadrunner.__version__)

print(os.getcwd())
# Out:
# sbmlutils: 0.1.5a5
# cobra: 0.6.1
# roadrunner: 1.4.18; Compiler: gcc 4.8.2, C++ version: 199711; JIT Compiler: LLVM-3.3; Date: May 17 2017, 17:41:04; LibSBML Version: 5.14.0
# /home/mkoenig/git/dfba/models/diauxic_growth

# %% [markdown]
# ## Simulation settings

# %%
model_id = "diauxic_growth"
tend = 20.0
dt = 0.05

# %%
def plot_results(df, mid):
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2, figsize=(14, 14))
    kwargs = {}
    for ax in (ax1, ax2):
        ax.plot(df.time, df['[Ac]'], color='darkred', label="Ac", **kwargs)
        ax.plot(df.time, df['[Glcxt]'], color='darkblue', label="Glcxt", **kwargs)
        ax.plot(df.time, df['[O2]'], color='darkgreen', label="O2", **kwargs)

    for ax in (ax3, ax4):
        ax.plot(df.time, df['[X]'], color='black', label="X biomass", **kwargs)

    ax2.set_yscale('log')
    ax2.set_ylim([10E-5, 15])
    ax4.set_yscale('log')

    for ax in (ax1, ax2):
        ax.set_ylabel('Concentration [?]')

    for ax in (ax3, ax4):
        ax.set_ylabel('Biomass [?]')

    for ax in (ax1, ax2):
        ax.set_title(mid)
        ax.set_xlabel('time [h]')
        ax.legend()
    plt.show()
    return fig

# %% [markdown]
# ## mk_model

# %%
version = 'v11'
sbml_mk = './mk/{}/diauxic_top.xml'.format(version)
mid_mk = '{}_mk_{}-sbmlutils.csv'.format(model_id, version)
print(sbml_mk)
print(mid_mk)

# run simulation 
df_mk, dfba_model_mk, dfba_simulator_mk = simulate_dfba(sbml_mk, tend=tend, dt=dt)
display(df_mk.head())
df_mk.to_csv('./{}.csv'.format(mid))

fig = plot_results(df_mk, mid_mk)
fig.savefig('./{}.png'.format(mid_mk), bbox_inches='tight')
# Out:
# ./mk/v11/diauxic_top.xml
# diauxic_growth_mk_v11-sbmlutils.csv
#
# Simulation time     : 1.433 [s]
# Total time          : 1.511 [s]
# Overhead time       : 0.078 [s] (5.1 %)
#       time      [Ac]    [Glcxt]      [O2]       [X]  [dummy_S]  [fba__Ac]  \
# 0.00  0.00  0.400000  10.800000  0.210000  0.001000        0.0        0.0
# 0.05  0.05  0.399921  10.799487  0.209356  0.001056        0.0        0.0
# 0.10  0.10  0.399838  10.798945  0.208877  0.001116        0.0        0.0
# 0.15  0.15  0.399750  10.798372  0.208509  0.001178        0.0        0.0
# 0.20  0.20  0.399657  10.797767  0.208217  0.001245        0.0        0.0
#
#       [fba__Glcxt]  [fba__O2]  [fba__X]   ...     lb_EX_O2  lb_EX_X    pEX_Ac  \
# 0.00           0.0        0.0       0.0   ...        -15.0    -10.0 -1.533756
# 0.05           0.0        0.0       0.0   ...        -15.0    -10.0 -1.533757
# 0.10           0.0        0.0       0.0   ...        -15.0    -10.0 -1.533758
# 0.15           0.0        0.0       0.0   ...        -15.0    -10.0 -1.533759
# 0.20           0.0        0.0       0.0   ...        -15.0    -10.0 -1.533761
#
#       pEX_Glcxt  pEX_O2     pEX_X  ub_EX_Ac  ub_EX_Glcxt  ub_EX_O2  ub_EX_X
# 0.00  -9.986130   -15.0  1.094515    1000.0       1000.0    1000.0   1000.0
# 0.05  -9.986130   -15.0  1.094514    1000.0       1000.0    1000.0   1000.0
# 0.10  -9.986129   -15.0  1.094514    1000.0       1000.0    1000.0   1000.0
# 0.15  -9.986128   -15.0  1.094514    1000.0       1000.0    1000.0   1000.0
# 0.20  -9.986128   -15.0  1.094514    1000.0       1000.0    1000.0   1000.0
#
# [5 rows x 49 columns]

# %% [markdown]
# ## lw model

# %%
version_lw = 'v3'
sbml_lw = './lw/{}/growth_top.xml'.format(version)
mid_lw = '{}_lw_{}-sbmlutils.csv'.format(model_id, version_lw)
print(sbml_lw)
print(mid_lw)

# run simulation 
df_lw, dfba_model_lw, dfba_simulator_lw = simulate_dfba(sbml_lw, tend=tend, dt=dt)
display(df_lw.head())
df_lw.to_csv('./{}.csv'.format(mid_lw)

fig = plot_results(df_lw, mid_lw)
fig.savefig('./{}.png'.format(mid_lw), bbox_inches='tight')
# Out:
# ./lw/v3/growth_top.xml
# cobra/io/sbml3.py:259 UserWarning: loading SBML model without fbc:strict="true"
# Simulation time     : 1.329 [s]
# Total time          : 1.542 [s]
# Overhead time       : 0.213 [s] (13.8 %)
#       time      [Ac]  [C1__Ac]  [C1__Glcxt]  [C1__O2]  [C1__X]    [Glcxt]  \
# 0.00  0.00  0.400000       0.0          0.0       0.0      0.0  10.800000
# 0.05  0.05  0.399921       0.0          0.0       0.0      0.0  10.799487
# 0.10  0.10  0.399838       0.0          0.0       0.0      0.0  10.798945
# 0.15  0.15  0.399751       0.0          0.0       0.0      0.0  10.798372
# 0.20  0.20  0.399658       0.0          0.0       0.0      0.0  10.797767
#
#           [O2]       [X]  [dummy]      ...        C2__Km     Km  \
# 0.00  0.210000  0.001000      0.0      ...         0.001  0.015
# 0.05  0.209359  0.001056      0.0      ...         0.001  0.015
# 0.10  0.208882  0.001116      0.0      ...         0.001  0.015
# 0.15  0.208517  0.001178      0.0      ...         0.001  0.015
# 0.20  0.208225  0.001245      0.0      ...         0.001  0.015
#
#       a_rate_uptake  a_uptake_max    dt  g_rate_uptake  g_uptake_max  \
# 0.00       1.533756        1000.0  0.01       9.986130      9.986130
# 0.05       1.533757        1000.0  0.01       9.986130      9.986130
# 0.10       1.533758        1000.0  0.01       9.986129      9.986129
# 0.15       1.533759        1000.0  0.01       9.986128      9.986128
# 0.20       1.533761        1000.0  0.01       9.986128      9.986128
#
#       o_rate_uptake  o_uptake_max  x_rate_growth
# 0.00           15.0          15.0       1.094515
# 0.05           15.0          15.0       1.094514
# 0.10           15.0          15.0       1.094514
# 0.15           15.0          15.0       1.094514
# 0.20           15.0          15.0       1.094514
#
# [5 rows x 36 columns]
